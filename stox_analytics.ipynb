# %%
from connect import *

# %%
u = Upstox()

# %%
df = u.getDfData('nifty50')

# %%
df.head()
# Out:
#        date      open     close  ema_open  ema_close
# 0  09:15:00  17177.45  17178.05  17373.01   17373.89
# 1  09:16:00  17176.95  17180.25  17367.71   17370.93
# 2  09:17:00  17181.10  17191.35  17373.18   17370.67
# 3  09:18:00  17191.45  17205.10  17374.53   17378.18
# 4  09:19:00  17205.40  17201.10  17379.00   17375.70

# %%
len(df)
# Out:
# 375

# %%
df.shape
# Out:
# (375, 5)

# %%
df.plot( 'date' , 'ema_close' )
# Out:
# <Axes: xlabel='date'>

# %%
df.plot( 'date' , 'close' )
# Out:
# <Axes: xlabel='date'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt
 
 
# setting the dimensions of the plot
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close', 'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/3892861812.py:12: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
import seaborn as sns

# %%
df2 = pd.DataFrame()

i = 0
while i < len(df):
# Out:
# '09:15:00'

# %%
df2 = df.iloc[::5]

# %%
df2
# Out:
#          date      open     close  ema_open  ema_close
# 0    09:15:00  17177.45  17178.05  17373.01   17373.89
# 5    09:20:00  17201.45  17187.80  17378.45   17374.80
# 10   09:25:00  17181.10  17184.75  17370.34   17371.23
# 15   09:30:00  17171.45  17166.70  17362.41   17362.66
# 20   09:35:00  17149.25  17143.95  17362.77   17360.27
# ..        ...       ...       ...       ...        ...
# 350  15:05:00  17146.10  17150.40  17307.26   17310.56
# 355  15:10:00  17149.75  17151.90  17329.27   17331.18
# 360  15:15:00  17160.00  17161.30  17348.52   17330.62
# 365  15:20:00  17154.85  17150.60  17349.33   17338.36
# 370  15:25:00  17150.80  17150.40  17348.28   17349.12
#
# [75 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df2[['date','close', 'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/586523508.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
d2["ema_close"]
# Out:
# 0      17373.89
# 5      17374.80
# 10     17371.23
# 15     17362.66
# 20     17360.27
#          ...
# 350    17310.56
# 355    17331.18
# 360    17330.62
# 365    17338.36
# 370    17349.12
# Name: ema_close, Length: 75, dtype: float64

# %%
d2['SMA10'] = d2['ema_close'].rolling(10).mean()

# %%
d2
# Out:
#          date     close  ema_close      SMA30      SMA10
# 0    09:15:00  17178.05   17373.89        NaN        NaN
# 5    09:20:00  17187.80   17374.80        NaN        NaN
# 10   09:25:00  17184.75   17371.23        NaN        NaN
# 15   09:30:00  17166.70   17362.66        NaN        NaN
# 20   09:35:00  17143.95   17360.27        NaN        NaN
# ..        ...       ...        ...        ...        ...
# 350  15:05:00  17150.40   17310.56  17329.644  17329.644
# 355  15:10:00  17151.90   17331.18  17327.346  17327.346
# 360  15:15:00  17161.30   17330.62  17324.118  17324.118
# 365  15:20:00  17150.60   17338.36  17324.082  17324.082
# 370  15:25:00  17150.40   17349.12  17324.714  17324.714
#
# [75 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = d2[['date','close', 'ema_close', 'SMA10']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/176946891.py:6: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
df['SMA10'] = df['ema_close'].rolling(10).mean()
df['SMA10_close'] = df['close'].rolling(10).mean()

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close',  'SMA10_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/826632752.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','ema_close',  'SMA10']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/2599517960.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
#ewm(com=None,span=None,halflife=None,alpha=None,min_periods=0,
#adjust=True,ignore_na=False,axis=0).mean()
df = df[['date', 'open', 'close', 'ema_open', 'ema_close']]

# %%
df
# Out:
#          date      open     close  ema_open  ema_close
# 0    09:15:00  17177.45  17178.05  17373.01   17373.89
# 1    09:16:00  17176.95  17180.25  17367.71   17370.93
# 2    09:17:00  17181.10  17191.35  17373.18   17370.67
# 3    09:18:00  17191.45  17205.10  17374.53   17378.18
# 4    09:19:00  17205.40  17201.10  17379.00   17375.70
# ..        ...       ...       ...       ...        ...
# 370  15:25:00  17150.80  17150.40  17348.28   17349.12
# 371  15:26:00  17150.95  17150.35  17339.55   17347.35
# 372  15:27:00  17150.30  17151.95  17347.10   17339.71
# 373  15:28:00  17151.20  17151.40  17357.44   17346.92
# 374  15:29:00  17150.90  17142.75  17361.30   17355.23
#
# [375 rows x 5 columns]

# %%
df['ema_close_p2']=df['close'].ewm(alpha=0.2).mean()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/4221078498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ema_close_p2']=df['close'].ewm(alpha=0.2).mean()

# %%
df
# Out:
#          date      open     close  ema_open  ema_close  ema_close_p2
# 0    09:15:00  17177.45  17178.05  17373.01   17373.89  17178.050000
# 1    09:16:00  17176.95  17180.25  17367.71   17370.93  17179.272222
# 2    09:17:00  17181.10  17191.35  17373.18   17370.67  17184.222131
# 3    09:18:00  17191.45  17205.10  17374.53   17378.18  17191.294580
# 4    09:19:00  17205.40  17201.10  17379.00   17375.70  17194.211471
# ..        ...       ...       ...       ...        ...           ...
# 370  15:25:00  17150.80  17150.40  17348.28   17349.12  17152.701241
# 371  15:26:00  17150.95  17150.35  17339.55   17347.35  17152.230993
# 372  15:27:00  17150.30  17151.95  17347.10   17339.71  17152.174794
# 373  15:28:00  17151.20  17151.40  17357.44   17346.92  17152.019835
# 374  15:29:00  17150.90  17142.75  17361.30   17355.23  17150.165868
#
# [375 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close',  'ema_close_p2']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/1133660793.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/3387141632.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
df['ema_close_p2_sma10']=df['ema_close_p2'].rolling(10).mean()

# %%
df
# Out:
#          date      open     close  ema_open  ema_close  ema_close_p2  \
# 0    09:15:00  17177.45  17178.05  17373.01   17373.89  17178.050000
# 1    09:16:00  17176.95  17180.25  17367.71   17370.93  17179.272222
# 2    09:17:00  17181.10  17191.35  17373.18   17370.67  17184.222131
# 3    09:18:00  17191.45  17205.10  17374.53   17378.18  17191.294580
# 4    09:19:00  17205.40  17201.10  17379.00   17375.70  17194.211471
# ..        ...       ...       ...       ...        ...           ...
# 370  15:25:00  17150.80  17150.40  17348.28   17349.12  17152.701241
# 371  15:26:00  17150.95  17150.35  17339.55   17347.35  17152.230993
# 372  15:27:00  17150.30  17151.95  17347.10   17339.71  17152.174794
# 373  15:28:00  17151.20  17151.40  17357.44   17346.92  17152.019835
# 374  15:29:00  17150.90  17142.75  17361.30   17355.23  17150.165868
#
#      ema_close_p2_sma10
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close','ema_close_p2',  'ema_close_p2_sma10']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/3882351238.py:6: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
df['ema_close_pD']=df['close'].ewm(alpha=0.2).mean()

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df[['date','close','ema_close_pD']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/2613235821.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
from connect import *
u = Upstox()
df1 = u.getDfData('nifty50')

# %%
df1
# Out:
#          date      open     close  ema_open  ema_close
# 0    09:15:00  17177.45  17178.05  17373.01   17373.89
# 1    09:16:00  17176.95  17180.25  17367.71   17370.93
# 2    09:17:00  17181.10  17191.35  17373.18   17370.67
# 3    09:18:00  17191.45  17205.10  17374.53   17378.18
# 4    09:19:00  17205.40  17201.10  17379.00   17375.70
# ..        ...       ...       ...       ...        ...
# 370  15:25:00  17150.80  17150.40  17348.28   17349.12
# 371  15:26:00  17150.95  17150.35  17339.55   17347.35
# 372  15:27:00  17150.30  17151.95  17347.10   17339.71
# 373  15:28:00  17151.20  17151.40  17357.44   17346.92
# 374  15:29:00  17150.90  17142.75  17361.30   17355.23
#
# [375 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
 
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_20188/1389031351.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
from connect import *
from datetime import datetime
start = datetime(2023, 3, 1)
end = datetime(2023, 3, 1)
u = Upstox()
df1 = u.getDfData('nifty50', start, end)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 6
#       4 end = datetime(2023, 3, 1)
#       5 u = Upstox()
# ----> 6 df1 = u.getDfData('nifty50', start, end)
#
# TypeError: Upstox.getDfData() takes 2 positional arguments but 4 were given
