# %%
from connect import *
from datetime import datetime
start = datetime(2023, 3, 1)
end = datetime(2023, 3, 2)
u = Upstox()
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 10), datetime(2023, 4, 11))
df1.head()
# Out:
# hello 123
#                   date      open     close      ema_open     ema_close
# 0  2023-04-10 09:15:00  41116.15  41065.90  41045.218160  41040.026064
# 1  2023-04-10 09:16:00  41059.90  41065.80  41046.686344  41042.603458
# 2  2023-04-10 09:17:00  41074.20  41061.45  41049.437709  41044.488112
# 3  2023-04-10 09:18:00  41061.10  41037.35  41050.603938  41043.774301
# 4  2023-04-10 09:19:00  41033.90  41046.70  41048.933545  41044.066871

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 10), datetime(2023, 4, 11))
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/1389031351.py:6: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 10), datetime(2023, 4, 11))
df1['ema_close_p3'] = df1['close'].ewm(alpha=0.3).mean()
d2 = df1[['date','close',  'ema_close_p3']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/778713762.py:7: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 6), datetime(2023, 4, 7))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3794429519.py:7: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 6), datetime(2023, 4, 7))
df1['ema_close_p3'] = df1['close'].ewm(alpha=0.3).mean()

df1.head()
d2 = df1[['date','close',  'ema_close_p3']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3758965223.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 5), datetime(2023, 4, 6))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3306380248.py:7: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 5), datetime(2023, 4, 6))
df1['ema_close_p3'] = df1['close'].ewm(alpha=0.3).mean()

df1.head()
d2 = df1[['date','close',  'ema_close_p3']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2917236822.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 3), datetime(2023, 4, 4))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/4236099648.py:7: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df1 = u.getDfData('nseindexniftybank', datetime(2023, 4, 3), datetime(2023, 4, 4))
df1['ema_close_p3'] = df1['close'].ewm(alpha=0.3).mean()

df1.head()
d2 = df1[['date','close',  'ema_close_p3']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2807715555.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 29
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/4175723327.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 28
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/1786831712.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 27
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3020517044.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 24
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/1792255936.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 23
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2282368723.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 22
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/4084259397.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 21
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2804451511.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 20
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3580665199.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 17
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/503649821.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 16
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3961135935.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 15
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2874970796.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 14
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2997308398.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 13
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/353949290.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 10
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3155298946.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 9
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/3959193761.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 8
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/2723176969.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 6
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/398293894.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 3
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/410988548.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 2
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/4245573613.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',

# %%
fig, ax = plt.subplots(figsize=(15, 10))
MONTH = 3
DATE = 1
df1 = u.getDfData('nseindexniftybank', datetime(2023, MONTH, DATE), datetime(2023, MONTH, (DATE+1)))
df1.head()
d2 = df1[['date','close',  'ema_close']]

#plot sales of each store with custom colors
sns.lineplot(x='date', y='value', hue='variable', 
             data=pd.melt(d2, ['date']),
             palette=['red', 'blue', 'purple', 'pink'], ax=ax)

plt.show()
# Out:
# hello 123
# /var/folders/g0/bmstjrcn73bdxfx69rwqwp6w0000gn/T/ipykernel_2133/297646892.py:9: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sns.lineplot(x='date', y='value', hue='variable',
